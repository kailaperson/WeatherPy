# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
from datetime import datetime

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | laurel
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | conway
# Processing Record 8 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | guaruja
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | biak
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | chattanooga
# Processing Record 23 of Set 1 | miri
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | abeche
# Processing Record 26 of Set 1 | veraval
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | narsaq
# Processing Record 29 of Set 1 | moose factory
# Processing Record 30 of Set 1 | georgetown
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | bilma
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | komsomolskiy
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | pisco
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | santiago del estero
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | bafra
# Processing Record 45 of Set 1 | poum
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | loukhi
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | yinchuan
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | isangel
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | yulara
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | caluquembe
# Processing Record 9 of Set 2 | nabire
# Processing Record 10 of Set 2 | minna
# Processing Record 11 of Set 2 | carutapera
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | yevpatoriya
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | padang
# Processing Record 17 of Set 2 | lamu
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | dwarka
# Processing Record 20 of Set 2 | carlagan
# Processing Record 21 of Set 2 | vondrozo
# Processing Record 22 of Set 2 | caravelas
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | portree
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | minab
# Processing Record 27 of Set 2 | gari
# Processing Record 28 of Set 2 | norman wells
# Processing Record 29 of Set 2 | tabuk
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | grindavik
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | punta arenas
# Processing Record 34 of Set 2 | ostrovnoy
# Processing Record 35 of Set 2 | broome
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | airai
# Processing Record 38 of Set 2 | alihe
# Processing Record 39 of Set 2 | beaufort
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | butaritari
# Processing Record 42 of Set 2 | surt
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | tuatapere
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | ningyang
# Processing Record 49 of Set 2 | bolama
# Processing Record 50 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 3 | norrtalje
# Processing Record 2 of Set 3 | rio gallegos
# Processing Record 3 of Set 3 | chuy
# Processing Record 4 of Set 3 | camapua
# Processing Record 5 of Set 3 | vargashi
# Processing Record 6 of Set 3 | ushumun
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | san andres
# Processing Record 11 of Set 3 | vardo
# Processing Record 12 of Set 3 | nanortalik
# Processing Record 13 of Set 3 | luderitz
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | tiksi
# Processing Record 16 of Set 3 | yumen
# Processing Record 17 of Set 3 | dunedin
# Processing Record 18 of Set 3 | faya
# Processing Record 19 of Set 3 | chengde
# Processing Record 20 of Set 3 | custoias
# Processing Record 21 of Set 3 | ust-nera
# Processing Record 22 of Set 3 | kichera
# Processing Record 23 of Set 3 | geraldton
# Processing Record 24 of Set 3 | deputatskiy
# Processing Record 25 of Set 3 | zhigansk
# Processing Record 26 of Set 3 | georgiyevskoye
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | hastings
# Processing Record 29 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 30 of Set 3 | ranong
# Processing Record 31 of Set 3 | bac lieu
# Processing Record 32 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 3 | grants
# Processing Record 34 of Set 3 | cidreira
# Processing Record 35 of Set 3 | ponta delgada
# Processing Record 36 of Set 3 | bougouni
# Processing Record 37 of Set 3 | general roca
# Processing Record 38 of Set 3 | lagoa
# Processing Record 39 of Set 3 | san pedro
# Processing Record 40 of Set 3 | talnakh
# Processing Record 41 of Set 3 | aklavik
# Processing Record 42 of Set 3 | sola
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | sinnamary
# Processing Record 45 of Set 3 | mezen
# Processing Record 46 of Set 3 | marion
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | santa fe
# Processing Record 49 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | kailua
# Processing Record 2 of Set 4 | ouadda
# Processing Record 3 of Set 4 | sooke
# Processing Record 4 of Set 4 | hamilton
# Processing Record 5 of Set 4 | santa maria
# Processing Record 6 of Set 4 | balkanabat
# Processing Record 7 of Set 4 | itarema
# Processing Record 8 of Set 4 | saleilua
# City not found. Skipping...
# Processing Record 9 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 4 | evensk
# Processing Record 12 of Set 4 | salumbar
# Processing Record 13 of Set 4 | angoche
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | vila franca do campo
# Processing Record 17 of Set 4 | chokwe
# Processing Record 18 of Set 4 | cherskiy
# Processing Record 19 of Set 4 | comodoro rivadavia
# Processing Record 20 of Set 4 | ahipara
# Processing Record 21 of Set 4 | mount gambier
# Processing Record 22 of Set 4 | nuuk
# Processing Record 23 of Set 4 | port hardy
# Processing Record 24 of Set 4 | ayagoz
# Processing Record 25 of Set 4 | bundaberg
# Processing Record 26 of Set 4 | coihaique
# Processing Record 27 of Set 4 | havre-saint-pierre
# Processing Record 28 of Set 4 | pemagatsel
# Processing Record 29 of Set 4 | beringovskiy
# Processing Record 30 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 31 of Set 4 | uthal
# Processing Record 32 of Set 4 | kaberamaido
# Processing Record 33 of Set 4 | sibolga
# Processing Record 34 of Set 4 | san joaquin
# Processing Record 35 of Set 4 | maykain
# City not found. Skipping...
# Processing Record 36 of Set 4 | ciras
# City not found. Skipping...
# Processing Record 37 of Set 4 | hovd
# Processing Record 38 of Set 4 | quelimane
# Processing Record 39 of Set 4 | novikovo
# Processing Record 40 of Set 4 | gazanjyk
# Processing Record 41 of Set 4 | tyukhtet
# Processing Record 42 of Set 4 | bonavista
# Processing Record 43 of Set 4 | olafsvik
# Processing Record 44 of Set 4 | cockburn town
# Processing Record 45 of Set 4 | ust-kuyga
# Processing Record 46 of Set 4 | muroto
# Processing Record 47 of Set 4 | west wendover
# Processing Record 48 of Set 4 | chama
# Processing Record 49 of Set 4 | east london
# Processing Record 50 of Set 4 | nago
# Processing Record 1 of Set 5 | bow island
# Processing Record 2 of Set 5 | katobu
# Processing Record 3 of Set 5 | tasiilaq
# Processing Record 4 of Set 5 | nazira
# Processing Record 5 of Set 5 | morro bay
# Processing Record 6 of Set 5 | lafia
# Processing Record 7 of Set 5 | batagay
# Processing Record 8 of Set 5 | turukhansk
# Processing Record 9 of Set 5 | antalya
# Processing Record 10 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 5 | stornoway
# Processing Record 13 of Set 5 | sharan
# Processing Record 14 of Set 5 | henties bay
# Processing Record 15 of Set 5 | sur
# Processing Record 16 of Set 5 | beloha
# Processing Record 17 of Set 5 | dakar
# Processing Record 18 of Set 5 | hami
# Processing Record 19 of Set 5 | ormond beach
# Processing Record 20 of Set 5 | cadiz
# Processing Record 21 of Set 5 | abu dhabi
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | tochigi
# Processing Record 25 of Set 5 | bubaque
# Processing Record 26 of Set 5 | laguna
# Processing Record 27 of Set 5 | marawi
# Processing Record 28 of Set 5 | sangar
# Processing Record 29 of Set 5 | hofn
# Processing Record 30 of Set 5 | sorong
# Processing Record 31 of Set 5 | tazovskiy
# Processing Record 32 of Set 5 | blankenberge
# Processing Record 33 of Set 5 | gazojak
# Processing Record 34 of Set 5 | babushkin
# Processing Record 35 of Set 5 | kedrovyy
# Processing Record 36 of Set 5 | orebro
# Processing Record 37 of Set 5 | yaan
# Processing Record 38 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 5 | nelson
# Processing Record 40 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 5 | ormara
# Processing Record 42 of Set 5 | vila velha
# Processing Record 43 of Set 5 | piltene
# Processing Record 44 of Set 5 | maldonado
# Processing Record 45 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 5 | tessalit
# Processing Record 47 of Set 5 | sungaipenuh
# Processing Record 48 of Set 5 | skjervoy
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | kulim
# Processing Record 1 of Set 6 | saint anthony
# Processing Record 2 of Set 6 | provideniya
# Processing Record 3 of Set 6 | phek
# Processing Record 4 of Set 6 | omboue
# Processing Record 5 of Set 6 | ushibuka
# Processing Record 6 of Set 6 | kysyl-syr
# Processing Record 7 of Set 6 | pombas
# Processing Record 8 of Set 6 | kavieng
# Processing Record 9 of Set 6 | kindu
# Processing Record 10 of Set 6 | chase
# Processing Record 11 of Set 6 | astorga
# Processing Record 12 of Set 6 | khorramshahr
# Processing Record 13 of Set 6 | vikhorevka
# Processing Record 14 of Set 6 | moron
# Processing Record 15 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | los llanos de aridane
# Processing Record 17 of Set 6 | longyearbyen
# Processing Record 18 of Set 6 | chiredzi
# Processing Record 19 of Set 6 | kurchum
# Processing Record 20 of Set 6 | jiblah
# Processing Record 21 of Set 6 | tobane
# Processing Record 22 of Set 6 | warri
# Processing Record 23 of Set 6 | port hawkesbury
# Processing Record 24 of Set 6 | ancud
# Processing Record 25 of Set 6 | tobermory
# Processing Record 26 of Set 6 | great yarmouth
# Processing Record 27 of Set 6 | baihar
# Processing Record 28 of Set 6 | flinders
# Processing Record 29 of Set 6 | faanui
# Processing Record 30 of Set 6 | bukama
# Processing Record 31 of Set 6 | sao filipe
# Processing Record 32 of Set 6 | madimba
# Processing Record 33 of Set 6 | fuling
# Processing Record 34 of Set 6 | whitehorse
# Processing Record 35 of Set 6 | noyabrsk
# Processing Record 36 of Set 6 | svinninge
# Processing Record 37 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 6 | nakapiripirit
# Processing Record 39 of Set 6 | kabirwala
# Processing Record 40 of Set 6 | namibe
# Processing Record 41 of Set 6 | shanting
# Processing Record 42 of Set 6 | gobabis
# Processing Record 43 of Set 6 | tecolotlan
# Processing Record 44 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 6 | lukovetskiy
# Processing Record 46 of Set 6 | port keats
# Processing Record 47 of Set 6 | paciran
# Processing Record 48 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 6 | las vegas
# Processing Record 50 of Set 6 | taiyuan
# Processing Record 1 of Set 7 | upernavik
# Processing Record 2 of Set 7 | esperance
# Processing Record 3 of Set 7 | saldanha
# Processing Record 4 of Set 7 | port lincoln
# Processing Record 5 of Set 7 | huilong
# Processing Record 6 of Set 7 | touros
# Processing Record 7 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 8 of Set 7 | rio grande
# Processing Record 9 of Set 7 | pevek
# Processing Record 10 of Set 7 | haines junction
# Processing Record 11 of Set 7 | antsirabe
# Processing Record 12 of Set 7 | bathsheba
# Processing Record 13 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 7 | leh
# Processing Record 15 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 7 | aksarka
# Processing Record 17 of Set 7 | barahona
# Processing Record 18 of Set 7 | khilok
# Processing Record 19 of Set 7 | yarmouth
# Processing Record 20 of Set 7 | haimen
# Processing Record 21 of Set 7 | danjiangkou
# Processing Record 22 of Set 7 | maniitsoq
# Processing Record 23 of Set 7 | lata
# Processing Record 24 of Set 7 | alugan
# Processing Record 25 of Set 7 | gamba
# Processing Record 26 of Set 7 | inhambane
# Processing Record 27 of Set 7 | niamey
# Processing Record 28 of Set 7 | pitea
# Processing Record 29 of Set 7 | kitwe
# Processing Record 30 of Set 7 | lompoc
# Processing Record 31 of Set 7 | paamiut
# Processing Record 32 of Set 7 | severo-kurilsk
# Processing Record 33 of Set 7 | fort dodge
# Processing Record 34 of Set 7 | tondano
# Processing Record 35 of Set 7 | neosho
# Processing Record 36 of Set 7 | newport
# Processing Record 37 of Set 7 | karratha
# Processing Record 38 of Set 7 | linxia
# Processing Record 39 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 7 | jepara
# Processing Record 41 of Set 7 | qasigiannguit
# Processing Record 42 of Set 7 | puerto escondido
# Processing Record 43 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 44 of Set 7 | cap-aux-meules
# Processing Record 45 of Set 7 | nelson bay
# Processing Record 46 of Set 7 | ilo
# Processing Record 47 of Set 7 | verkhoyansk
# Processing Record 48 of Set 7 | custodia
# Processing Record 49 of Set 7 | corpus christi
# Processing Record 50 of Set 7 | plotnikovo
# Processing Record 1 of Set 8 | bambous virieux
# Processing Record 2 of Set 8 | verkhnyaya tura
# Processing Record 3 of Set 8 | marzuq
# Processing Record 4 of Set 8 | yeppoon
# Processing Record 5 of Set 8 | namatanai
# Processing Record 6 of Set 8 | tolaga bay
# Processing Record 7 of Set 8 | bratsk
# Processing Record 8 of Set 8 | rujewa
# Processing Record 9 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 8 | leningradskiy
# Processing Record 11 of Set 8 | sorland
# Processing Record 12 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 8 | port hedland
# Processing Record 14 of Set 8 | susa
# Processing Record 15 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 8 | keetmanshoop
# Processing Record 17 of Set 8 | ancona
# Processing Record 18 of Set 8 | necochea
# Processing Record 19 of Set 8 | alofi
# Processing Record 20 of Set 8 | khislavichi
# Processing Record 21 of Set 8 | port blair
# Processing Record 22 of Set 8 | lavrentiya
# Processing Record 23 of Set 8 | raga
# Processing Record 24 of Set 8 | coquimbo
# Processing Record 25 of Set 8 | saint-francois
# Processing Record 26 of Set 8 | baragua
# Processing Record 27 of Set 8 | broken hill
# Processing Record 28 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 8 | fort nelson
# Processing Record 30 of Set 8 | midland
# Processing Record 31 of Set 8 | constitucion
# Processing Record 32 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 8 | nacozari
# Processing Record 34 of Set 8 | pringsewu
# Processing Record 35 of Set 8 | nuevitas
# Processing Record 36 of Set 8 | monrovia
# Processing Record 37 of Set 8 | salinas
# Processing Record 38 of Set 8 | meulaboh
# Processing Record 39 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 41 of Set 8 | castro
# Processing Record 42 of Set 8 | san patricio
# Processing Record 43 of Set 8 | anadyr
# Processing Record 44 of Set 8 | tsogni
# Processing Record 45 of Set 8 | orlik
# Processing Record 46 of Set 8 | ixtapa
# Processing Record 47 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 8 | clarksville
# Processing Record 49 of Set 8 | bone
# Processing Record 50 of Set 8 | zaozerne
# Processing Record 1 of Set 9 | celestun
# Processing Record 2 of Set 9 | weligama
# Processing Record 3 of Set 9 | bintulu
# Processing Record 4 of Set 9 | freetown
# Processing Record 5 of Set 9 | aykhal
# Processing Record 6 of Set 9 | tokonou
# Processing Record 7 of Set 9 | chuka
# Processing Record 8 of Set 9 | pangody
# Processing Record 9 of Set 9 | zaltan
# Processing Record 10 of Set 9 | sarakhs
# Processing Record 11 of Set 9 | new richmond
# Processing Record 12 of Set 9 | half moon bay
# Processing Record 13 of Set 9 | nome
# Processing Record 14 of Set 9 | utete
# Processing Record 15 of Set 9 | verkh-chebula
# Processing Record 16 of Set 9 | manadhoo
# Processing Record 17 of Set 9 | xuddur
# Processing Record 18 of Set 9 | valparaiso
# Processing Record 19 of Set 9 | kiunga
# Processing Record 20 of Set 9 | richards bay
# Processing Record 21 of Set 9 | pacific grove
# Processing Record 22 of Set 9 | bafoussam
# Processing Record 23 of Set 9 | warrington
# Processing Record 24 of Set 9 | cilegon
# Processing Record 25 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 9 | walvis bay
# Processing Record 27 of Set 9 | jiaozuo
# Processing Record 28 of Set 9 | nichinan
# Processing Record 29 of Set 9 | labytnangi
# Processing Record 30 of Set 9 | guaymas
# Processing Record 31 of Set 9 | rabo de peixe
# Processing Record 32 of Set 9 | ilulissat
# Processing Record 33 of Set 9 | nador
# Processing Record 34 of Set 9 | guaxupe
# Processing Record 35 of Set 9 | awjilah
# Processing Record 36 of Set 9 | rio bananal
# Processing Record 37 of Set 9 | ornskoldsvik
# Processing Record 38 of Set 9 | waipawa
# Processing Record 39 of Set 9 | ahuimanu
# Processing Record 40 of Set 9 | san policarpo
# Processing Record 41 of Set 9 | acapulco
# Processing Record 42 of Set 9 | dobson
# Processing Record 43 of Set 9 | dinar
# Processing Record 44 of Set 9 | aquiraz
# Processing Record 45 of Set 9 | toora-khem
# Processing Record 46 of Set 9 | luena
# Processing Record 47 of Set 9 | gulaothi
# Processing Record 48 of Set 9 | sajanan
# Processing Record 49 of Set 9 | saint-augustin
# Processing Record 50 of Set 9 | alta floresta
# Processing Record 1 of Set 10 | kruisfontein
# Processing Record 2 of Set 10 | kalmunai
# Processing Record 3 of Set 10 | marsh harbour
# Processing Record 4 of Set 10 | kasongo-lunda
# Processing Record 5 of Set 10 | riyadh
# Processing Record 6 of Set 10 | verkhnevilyuysk
# Processing Record 7 of Set 10 | gao
# Processing Record 8 of Set 10 | dakoro
# Processing Record 9 of Set 10 | port-gentil
# Processing Record 10 of Set 10 | cap malheureux
# Processing Record 11 of Set 10 | adrar
# Processing Record 12 of Set 10 | sistranda
# Processing Record 13 of Set 10 | bima
# Processing Record 14 of Set 10 | miquelon
# Processing Record 15 of Set 10 | atar
# Processing Record 16 of Set 10 | zavyalovo
# Processing Record 17 of Set 10 | turayf
# Processing Record 18 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 19 of Set 10 | te anau
# Processing Record 20 of Set 10 | port augusta
# Processing Record 21 of Set 10 | porto velho
# Processing Record 22 of Set 10 | sabang
# Processing Record 23 of Set 10 | eyl
# Processing Record 24 of Set 10 | pangnirtung
# Processing Record 25 of Set 10 | kirakira
# Processing Record 26 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 27 of Set 10 | kavaratti
# Processing Record 28 of Set 10 | high level
# Processing Record 29 of Set 10 | lugovoy
# Processing Record 30 of Set 10 | jardim
# Processing Record 31 of Set 10 | dalbandin
# Processing Record 32 of Set 10 | berlevag
# Processing Record 33 of Set 10 | rosetta
# Processing Record 34 of Set 10 | salmas
# Processing Record 35 of Set 10 | wairoa
# Processing Record 36 of Set 10 | egvekinot
# Processing Record 37 of Set 10 | grand gaube
# Processing Record 38 of Set 10 | pinawa
# Processing Record 39 of Set 10 | kandrian
# Processing Record 40 of Set 10 | tobol
# Processing Record 41 of Set 10 | flin flon
# Processing Record 42 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 10 | neuquen
# Processing Record 44 of Set 10 | sherlovaya gora
# Processing Record 45 of Set 10 | kamenka
# Processing Record 46 of Set 10 | vanavara
# Processing Record 47 of Set 10 | victoria
# Processing Record 48 of Set 10 | galich
# Processing Record 49 of Set 10 | liptovsky hradok
# Processing Record 50 of Set 10 | brae
# Processing Record 1 of Set 11 | melfi
# Processing Record 2 of Set 11 | spas-klepiki
# Processing Record 3 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 11 | awbari
# Processing Record 5 of Set 11 | rocha
# Processing Record 6 of Set 11 | la ronge
# Processing Record 7 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 11 | san ignacio
# Processing Record 9 of Set 11 | itapema
# Processing Record 10 of Set 11 | lorengau
# Processing Record 11 of Set 11 | kopervik
# Processing Record 12 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 13 of Set 11 | sonoita
# Processing Record 14 of Set 11 | kawalu
# Processing Record 15 of Set 11 | harbin
# Processing Record 16 of Set 11 | clyde river
# Processing Record 17 of Set 11 | saint-georges
# Processing Record 18 of Set 11 | sun valley
# Processing Record 19 of Set 11 | saskylakh
# Processing Record 20 of Set 11 | hayrabolu
# Processing Record 21 of Set 11 | ossora
# Processing Record 22 of Set 11 | san quintin
# Processing Record 23 of Set 11 | tha chang
# Processing Record 24 of Set 11 | independence
# Processing Record 25 of Set 11 | port macquarie
# Processing Record 26 of Set 11 | bafata
# Processing Record 27 of Set 11 | yantal
# Processing Record 28 of Set 11 | srednekolymsk
# Processing Record 29 of Set 11 | santa cruz do rio pardo
# Processing Record 30 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 31 of Set 11 | mao
# Processing Record 32 of Set 11 | sri aman
# Processing Record 33 of Set 11 | codrington
# Processing Record 34 of Set 11 | mazara del vallo
# Processing Record 35 of Set 11 | tortoli
# Processing Record 36 of Set 11 | ray
# Processing Record 37 of Set 11 | vrangel
# Processing Record 38 of Set 11 | kapoeta
# Processing Record 39 of Set 11 | prince rupert
# Processing Record 40 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 11 | fort-shevchenko
# Processing Record 42 of Set 11 | darhan
# Processing Record 43 of Set 11 | margate
# Processing Record 44 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | moussoro
# Processing Record 46 of Set 11 | yarada
# Processing Record 47 of Set 11 | kudahuvadhoo
# Processing Record 48 of Set 11 | mana
# Processing Record 49 of Set 11 | fortuna
# Processing Record 50 of Set 11 | sinjah
# City not found. Skipping...
# Processing Record 1 of Set 12 | alice springs
# Processing Record 2 of Set 12 | olavarria
# Processing Record 3 of Set 12 | chara
# Processing Record 4 of Set 12 | sayyan
# Processing Record 5 of Set 12 | zhezkazgan
# Processing Record 6 of Set 12 | ust-karsk
# Processing Record 7 of Set 12 | morant bay
# Processing Record 8 of Set 12 | gizo
# Processing Record 9 of Set 12 | belmonte
# Processing Record 10 of Set 12 | paita
# Processing Record 11 of Set 12 | sioux lookout
# Processing Record 12 of Set 12 | viedma
# Processing Record 13 of Set 12 | llanes
# Processing Record 14 of Set 12 | tura
# Processing Record 15 of Set 12 | beloeil
# Processing Record 16 of Set 12 | lithgow
# Processing Record 17 of Set 12 | rapid valley
# Processing Record 18 of Set 12 | launceston
# Processing Record 19 of Set 12 | uige
# Processing Record 20 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 21 of Set 12 | wilmington
# Processing Record 22 of Set 12 | korla
# Processing Record 23 of Set 12 | paldiski
# Processing Record 24 of Set 12 | kaeo
# Processing Record 25 of Set 12 | mirnyy
# Processing Record 26 of Set 12 | barra do garcas
# Processing Record 27 of Set 12 | tikapur
# Processing Record 28 of Set 12 | havelock
# Processing Record 29 of Set 12 | huarmey
# Processing Record 30 of Set 12 | mpwapwa
# Processing Record 31 of Set 12 | katsuura
# Processing Record 32 of Set 12 | muros
# Processing Record 33 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 34 of Set 12 | asosa
# Processing Record 35 of Set 12 | borujan
# City not found. Skipping...
# Processing Record 36 of Set 12 | north platte
# Processing Record 37 of Set 12 | praia da vitoria
# Processing Record 38 of Set 12 | otavi
# Processing Record 39 of Set 12 | ambon
# Processing Record 40 of Set 12 | anju
# Processing Record 41 of Set 12 | pedernales
# Processing Record 42 of Set 12 | yankton
# Processing Record 43 of Set 12 | quatre cocos
# Processing Record 44 of Set 12 | kahului
# Processing Record 45 of Set 12 | odweyne
# Processing Record 46 of Set 12 | takhli
# Processing Record 47 of Set 12 | nurota
# Processing Record 48 of Set 12 | el cobre
# Processing Record 49 of Set 12 | houma
# Processing Record 50 of Set 12 | sao joao da barra
# Processing Record 1 of Set 13 | alexandria
# Processing Record 2 of Set 13 | papara
# Processing Record 3 of Set 13 | trincomalee
# Processing Record 4 of Set 13 | baykit
# Processing Record 5 of Set 13 | druzhba
# Processing Record 6 of Set 13 | alyangula
# Processing Record 7 of Set 13 | portland
# Processing Record 8 of Set 13 | vuktyl
# Processing Record 9 of Set 13 | udachnyy
# Processing Record 10 of Set 13 | buraydah
# Processing Record 11 of Set 13 | honiara
# Processing Record 12 of Set 13 | altay
# Processing Record 13 of Set 13 | honningsvag
# Processing Record 14 of Set 13 | punta cardon
# Processing Record 15 of Set 13 | molina de segura
# Processing Record 16 of Set 13 | asau
# Processing Record 17 of Set 13 | eureka
# Processing Record 18 of Set 13 | kinsale
# Processing Record 19 of Set 13 | kokopo
# Processing Record 20 of Set 13 | westport
# Processing Record 21 of Set 13 | lafayette
# Processing Record 22 of Set 13 | northam
# Processing Record 23 of Set 13 | tomatlan
# Processing Record 24 of Set 13 | charleston
# Processing Record 25 of Set 13 | omsukchan
# Processing Record 26 of Set 13 | beidao
# Processing Record 27 of Set 13 | puerto baquerizo moreno
# Processing Record 28 of Set 13 | taltal
# Processing Record 29 of Set 13 | strezhevoy
# Processing Record 30 of Set 13 | elliot
# Processing Record 31 of Set 13 | itau de minas
# Processing Record 32 of Set 13 | dali
# Processing Record 33 of Set 13 | chicama
# Processing Record 34 of Set 13 | buritis
# Processing Record 35 of Set 13 | morondava
# Processing Record 36 of Set 13 | la rioja
# Processing Record 37 of Set 13 | ambovombe
# Processing Record 38 of Set 13 | durazno
# Processing Record 39 of Set 13 | pasni
# Processing Record 40 of Set 13 | lasa
# Processing Record 41 of Set 13 | angelokastron
# City not found. Skipping...
# Processing Record 42 of Set 13 | pulsano
# Processing Record 43 of Set 13 | xining
# Processing Record 44 of Set 13 | hille
# Processing Record 45 of Set 13 | osa
# Processing Record 46 of Set 13 | jalu
# Processing Record 47 of Set 13 | ban dung
# Processing Record 48 of Set 13 | bereda
# Processing Record 49 of Set 13 | bagdarin
# Processing Record 50 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 14 | craig
# Processing Record 2 of Set 14 | katangli
# Processing Record 3 of Set 14 | zhaoqing
# Processing Record 4 of Set 14 | san juan
# Processing Record 5 of Set 14 | giyani
# Processing Record 6 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 14 | ayan
# Processing Record 8 of Set 14 | sovetskiy
# Processing Record 9 of Set 14 | iquitos
# Processing Record 10 of Set 14 | santa isabel do rio negro
# Processing Record 11 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 14 | homer
# Processing Record 13 of Set 14 | harwich
# Processing Record 14 of Set 14 | koslan
# Processing Record 15 of Set 14 | nouadhibou
# Processing Record 16 of Set 14 | concordia
# Processing Record 17 of Set 14 | talcahuano
# Processing Record 18 of Set 14 | plettenberg bay
# Processing Record 19 of Set 14 | popondetta
# Processing Record 20 of Set 14 | kupang
# Processing Record 21 of Set 14 | cabra
# Processing Record 22 of Set 14 | bay roberts
# Processing Record 23 of Set 14 | emba
# Processing Record 24 of Set 14 | adiake
# Processing Record 25 of Set 14 | forssa
# Processing Record 26 of Set 14 | laredo
# Processing Record 27 of Set 14 | ekhabi
# Processing Record 28 of Set 14 | ingham
# Processing Record 29 of Set 14 | tucumcari
# Processing Record 30 of Set 14 | el seibo
# Processing Record 31 of Set 14 | atoyac
# Processing Record 32 of Set 14 | conceicao do mato dentro
# Processing Record 33 of Set 14 | tailai
# Processing Record 34 of Set 14 | yayva
# Processing Record 35 of Set 14 | upata
# Processing Record 36 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 14 | lingao
# Processing Record 38 of Set 14 | mato verde
# Processing Record 39 of Set 14 | malanje
# Processing Record 40 of Set 14 | lusambo
# Processing Record 41 of Set 14 | rudnaya pristan
# Processing Record 42 of Set 14 | hobyo
# Processing Record 43 of Set 14 | tual
# Processing Record 44 of Set 14 | betioky
# Processing Record 45 of Set 14 | nizhniy tsasuchey
# Processing Record 46 of Set 14 | itanagar
# Processing Record 47 of Set 14 | ankazobe
# Processing Record 48 of Set 14 | grande prairie
# Processing Record 49 of Set 14 | dukat
# Processing Record 50 of Set 14 | boda
# Processing Record 1 of Set 15 | muravlenko
# Processing Record 2 of Set 15 | coos bay
# Processing Record 3 of Set 15 | rio claro
# Processing Record 4 of Set 15 | rundu
# Processing Record 5 of Set 15 | elat
# Processing Record 6 of Set 15 | suntar
# Processing Record 7 of Set 15 | sahuaripa
# Processing Record 8 of Set 15 | kuryk
# Processing Record 9 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 10 of Set 15 | caraquet
# Processing Record 11 of Set 15 | clonakilty
# Processing Record 12 of Set 15 | sam chuk
# Processing Record 13 of Set 15 | kon tum
# Processing Record 14 of Set 15 | moche
# Processing Record 15 of Set 15 | bara
# Processing Record 16 of Set 15 | tagusao
# Processing Record 17 of Set 15 | thunder bay
# Processing Record 18 of Set 15 | college
# Processing Record 19 of Set 15 | muzhi
# Processing Record 20 of Set 15 | straumen
# Processing Record 21 of Set 15 | ust-kulom
# Processing Record 22 of Set 15 | buenos aires
# Processing Record 23 of Set 15 | escanaba
# Processing Record 24 of Set 15 | sumbe
# Processing Record 25 of Set 15 | peterhead
# Processing Record 26 of Set 15 | kristiinankaupunki
# Processing Record 27 of Set 15 | kutum
# Processing Record 28 of Set 15 | cravo norte
# Processing Record 29 of Set 15 | kenai
# Processing Record 30 of Set 15 | ucluelet
# Processing Record 31 of Set 15 | jinchang
# Processing Record 32 of Set 15 | fairbanks
# Processing Record 33 of Set 15 | yacuiba
# Processing Record 34 of Set 15 | mehamn
# Processing Record 35 of Set 15 | ponezhukay
# Processing Record 36 of Set 15 | tommot
# Processing Record 37 of Set 15 | yarim
# Processing Record 38 of Set 15 | negombo
# Processing Record 39 of Set 15 | dulovo
# Processing Record 40 of Set 15 | balikpapan
# Processing Record 41 of Set 15 | hambantota
# Processing Record 42 of Set 15 | gannan
# Processing Record 43 of Set 15 | kuala terengganu
# Processing Record 44 of Set 15 | lipari
# Processing Record 45 of Set 15 | athens
# Processing Record 46 of Set 15 | lathi
# Processing Record 47 of Set 15 | new albany
# Processing Record 48 of Set 15 | niagara falls
# Processing Record 49 of Set 15 | pucallpa
# Processing Record 50 of Set 15 | banda aceh
# Processing Record 1 of Set 16 | vanimo
# Processing Record 2 of Set 16 | araouane
# Processing Record 3 of Set 16 | bababe
# City not found. Skipping...
# Processing Record 4 of Set 16 | ribeira brava
# Processing Record 5 of Set 16 | jablah
# Processing Record 6 of Set 16 | camalu
# Processing Record 7 of Set 16 | camp verde
# Processing Record 8 of Set 16 | lalawigan
# Processing Record 9 of Set 16 | gat
# Processing Record 10 of Set 16 | acarau
# Processing Record 11 of Set 16 | uvalde
# Processing Record 12 of Set 16 | salalah
# Processing Record 13 of Set 16 | morristown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Thompson  55.7435  -97.8558     82.56        39           0
# 1        Laurel  39.0993  -76.8483     92.44        55          40
# 2       Mataura -46.1927  168.8643     41.49        90          89
# 3          Hilo  19.7297 -155.0900     85.28        86          75
# 4      Bengkulu  -3.8004  102.2655     76.46        92          59
# 5        Conway  35.0887  -92.4421    100.81        44           0
# 6  Saint George  37.1041 -113.5841    104.79        20           0
# 7       Guaruja -23.9931  -46.2564     69.66        88         100
# 8    Nikolskoye  59.7035   30.7861     62.49        95          51
# 9        Avarua -21.2078 -159.7750     73.45        68          40
#
#    Wind Speed Country      Current Description
# 0       11.50      CA                    smoke
# 1        6.91      US         scattered clouds
# 2        3.18      NZ          overcast clouds
# 3        8.05      US               light rain
# 4        4.68      ID            broken clouds
# 5        3.00      US                clear sky
# 6        5.01      US                clear sky
# 7        3.44      BR  light intensity drizzle
# 8        5.14      RU            broken clouds
# 9        8.05      CK         scattered clouds

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
new_column_order =['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Thompson      CA  55.7435  -97.8558     82.56        39           0
# 1        Laurel      US  39.0993  -76.8483     92.44        55          40
# 2       Mataura      NZ -46.1927  168.8643     41.49        90          89
# 3          Hilo      US  19.7297 -155.0900     85.28        86          75
# 4      Bengkulu      ID  -3.8004  102.2655     76.46        92          59
# 5        Conway      US  35.0887  -92.4421    100.81        44           0
# 6  Saint George      US  37.1041 -113.5841    104.79        20           0
# 7       Guaruja      BR -23.9931  -46.2564     69.66        88         100
# 8    Nikolskoye      RU  59.7035   30.7861     62.49        95          51
# 9        Avarua      CK -21.2078 -159.7750     73.45        68          40
#
#    Wind Speed      Current Description
# 0       11.50                    smoke
# 1        6.91         scattered clouds
# 2        3.18          overcast clouds
# 3        8.05               light rain
# 4        4.68            broken clouds
# 5        3.00                clear sky
# 6        5.01                clear sky
# 7        3.44  light intensity drizzle
# 8        5.14            broken clouds
# 9        8.05         scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
